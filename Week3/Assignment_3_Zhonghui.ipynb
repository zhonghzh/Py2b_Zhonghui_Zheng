# %%
import numpy as np
import pandas as pd
df = pd.read_csv("winequality-red.csv")
df
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1595            6.2             0.600         0.08             2.0      0.090
# 1596            5.9             0.550         0.10             2.2      0.062
# 1597            6.3             0.510         0.13             2.3      0.076
# 1598            5.9             0.645         0.12             2.0      0.075
# 1599            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
samples=len(df)
columns=len(df.columns)
print(samples,columns)
# Out:
# 1600 12

# %%
def count_nan():
        for col in df.columns:
            column_name = col
            working_col = df[col]
            working_col_missing_samp = working_col.isna().sum()
            print(f"The column {column_name} is missing {working_col_missing_samp/columns*100}% of data! ")        
count_nan()
# Out:
# The column fixed acidity is missing 8.333333333333332% of data!
# The column volatile acidity is missing 8.333333333333332% of data!
# The column citric acid is missing 8.333333333333332% of data!
# The column residual sugar is missing 8.333333333333332% of data!
# The column chlorides is missing 8.333333333333332% of data!
# The column free sulfur dioxide is missing 8.333333333333332% of data!
# The column total sulfur dioxide is missing 8.333333333333332% of data!
# The column density is missing 8.333333333333332% of data!
# The column pH is missing 8.333333333333332% of data!
# The column sulphates is missing 8.333333333333332% of data!
# The column alcohol is missing 8.333333333333332% of data!
# The column quality is missing 8.333333333333332% of data!

# %%
nan_samples = df[df.isna().all(axis=1)]
nan_indexes = nan_samples.index.values
df = df.drop(nan_indexes)
count_nan()
# Out:
# The column fixed acidity is missing 0.0% of data!
# The column volatile acidity is missing 0.0% of data!
# The column citric acid is missing 0.0% of data!
# The column residual sugar is missing 0.0% of data!
# The column chlorides is missing 0.0% of data!
# The column free sulfur dioxide is missing 0.0% of data!
# The column total sulfur dioxide is missing 0.0% of data!
# The column density is missing 0.0% of data!
# The column pH is missing 0.0% of data!
# The column sulphates is missing 0.0% of data!
# The column alcohol is missing 0.0% of data!
# The column quality is missing 0.0% of data!

# %%
df = df.sort_values("quality")
df = df.reset_index(drop=True)
df
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.1             0.875         0.05             5.7      0.082
# 1              10.4             0.440         0.42             1.5      0.145
# 2               8.3             1.020         0.02             3.4      0.084
# 3               6.8             0.815         0.00             1.2      0.267
# 4              11.6             0.580         0.66             2.2      0.074
# ...             ...               ...          ...             ...        ...
# 1594            5.0             0.420         0.24             2.0      0.060
# 1595            5.5             0.490         0.03             1.8      0.044
# 1596            7.2             0.380         0.31             2.0      0.056
# 1597           11.3             0.620         0.67             5.2      0.086
# 1598            7.4             0.360         0.30             1.8      0.074
#
# ...

# %%
def normalize_values(col_value, min_val, max_val):
    normalized_val = np.divide(col_value - min_val, max_val - min_val)
    return normalized_val

def main():
    for column in df.columns:
        col_value = df[column]
        min_val = df[column].min()
        max_val = df[column].max()
        df[column] = normalize_values(col_value, min_val, max_val)


main()
df.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1599.000000       1599.000000  1599.000000     1599.000000
# mean        0.329171          0.279329     0.270976        0.112247
# std         0.154079          0.122644     0.194801        0.096570
# min         0.000000          0.000000     0.000000        0.000000
# 25%         0.221239          0.184932     0.090000        0.068493
# 50%         0.292035          0.273973     0.260000        0.089041
# 75%         0.407080          0.356164     0.420000        0.116438
# max         1.000000          1.000000     1.000000        1.000000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1599.000000          1599.000000           1599.000000  1599.000000
# mean      0.125988             0.209506              0.142996     0.490211
# std       0.078573             0.147326              0.116238     0.138571
# ...
